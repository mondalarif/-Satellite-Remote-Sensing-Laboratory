# %%
import os
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
path='/home/arif/Desktop/Python Lab'
os.chdir(path)

df1=pd.read_csv('chemin_2227.csv')

# %%
mineral=df1["MINERAL"]
percentage=df1["PERCENT"]

# %%
plt.figure(figsize=(10, 10))
plt.pie(percentage, labels=mineral, autopct='%1.1f%%')
plt.title("Mineral Percentage Distribution")
plt.show()
