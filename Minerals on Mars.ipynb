# %%
import os
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
path='/home/arif/Desktop/Python Lab'
os.chdir(path)

df=pd.read_csv('apxs_rsp_2245.csv')

# %%
df
# Out:
#       x-ray energy  count
# 0            483.1   7200
# 1            507.5      0
# 2            531.8      0
# 3            556.2      0
# 4            580.5      0
# ...            ...    ...
# 1018       25282.5     34
# 1019       25306.9     19
# 1020       25331.2     32
# 1021       25355.6     21
# 1022       25379.9     34
#
# [1023 rows x 2 columns]

# %%
energy=df['x-ray energy']
count=df['count']
energy_kev=energy/1000

# %%
plt.figure(figsize=(15,6))
plt.plot(energy_kev,count, "ro", linestyle="--", linewidth=2)
plt.xlabel('X ray energy (keV)')
plt.ylabel('Counts (a.u)')
# Out:
# Text(0, 0.5, 'Counts (a.u)')

# %%
plt.figure(figsize=(15,6))
plt.plot(energy_kev,count, "ro", linestyle="--", linewidth=2)
plt.xlabel('X ray energy (keV)')
plt.ylabel('Counts (a.u)')
plt.xlim(0,8)
plt.xticks(np.arange(0.5, 8.5, 0.5))
# Out:
# ([<matplotlib.axis.XTick at 0x7aa89da5f970>,
# ...
#  [Text(0.5, 0, '0.5'),
#   Text(1.0, 0, '1.0'),
#   Text(1.5, 0, '1.5'),
#   Text(2.0, 0, '2.0'),
#   Text(2.5, 0, '2.5'),
#   Text(3.0, 0, '3.0'),
#   Text(3.5, 0, '3.5'),
#   Text(4.0, 0, '4.0'),
#   Text(4.5, 0, '4.5'),
#   Text(5.0, 0, '5.0'),
#   Text(5.5, 0, '5.5'),
#   Text(6.0, 0, '6.0'),
#   Text(6.5, 0, '6.5'),
#   Text(7.0, 0, '7.0'),
#   Text(7.5, 0, '7.5'),
#   Text(8.0, 0, '8.0')])

# %%
fig, ax = plt.subplots(figsize=(15, 6))
ax.plot(energy_kev, count, "ro", linestyle="--", linewidth=2)

ax.set_xlabel('X ray energy (keV)', fontsize=14, fontweight="bold")
ax.set_ylabel('Counts (a.u)', fontsize=14, fontweight="bold")

ax.set_xlim(0, 8)
ax.set_xticks(np.arange(0.5, 8.5, 0.5))
ax.tick_params(axis='x', labelsize=14, width=2)
ax.tick_params(axis='y', labelsize=14, width=2)

ax.tick_params(axis='both', length=5, width=2)

for spine in ax.spines.values():
    spine.set_linewidth(2)


plt.savefig("/home/arif/Desktop/Python Lab/apxs_spectrum.png", dpi=300)
plt.show()
